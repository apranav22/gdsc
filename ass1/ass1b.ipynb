# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# q1

# %%
test = np.random.randint(1,100,(4, 4, 4))
mean  = test.mean()
print(mean)
# Out:
# 49.25

# %% [markdown]
# q2

# %%
df = pd.read_csv('iris.csv')
print(df[df['sepal length (cm)'] > 3.0].head())
# Out:
#    Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0           0                5.1               3.5                1.4
# 1           1                4.9               3.0                1.4
# 2           2                4.7               3.2                1.3
# 3           3                4.6               3.1                1.5
# 4           4                5.0               3.6                1.4
#
#    petal width (cm)
# 0               0.2
# 1               0.2
# 2               0.2
# 3               0.2
# 4               0.2

# %% [markdown]
# q3

# %%
plt.plot(df['petal length (cm)'], label='petal length (cm)')
plt.title('q3')
plt.legend()

# %% [markdown]
# q4

# %%
df2 = pd.DataFrame(test[:,:,0], columns=list('ABCD'))
df2.fillna(mean, inplace=True)
df2.sort_values(by=['A', 'B'],inplace=True)

# %% [markdown]
# q5

# %%
m1 = test[:,:,0]
m2 = test[:,:,1]
res = m1 @ m2
print(np.linalg.det(res))
# Out:
# -80478775623360.67

# %% [markdown]
# q6

# %%
print(df2.groupby(['A'])['B'].sum())
# Out:
# A
# 11     46
# 34     16
# 96    154
# Name: B, dtype: int32

# %% [markdown]
# q7

# %%
plt.hist(df['sepal length (cm)'], bins=10)
plt.grid(visible=True)

# %% [markdown]
# q8

# %%
test2 = np.random.randint(0,100,(4,4))
print(test2[:, 0])
# Out:
# [11 72 95 62]

# %% [markdown]
# q9

# %% [markdown]
# q10

# %%
plt.scatter(df['petal length (cm)'], df['sepal length (cm)'], s=10, c='red')
plt.scatter
# Out:
# <function matplotlib.pyplot.scatter(x: 'float | ArrayLike', y: 'float | ArrayLike', s: 'float | ArrayLike | None' = None, c: 'ArrayLike | Sequence[ColorType] | ColorType | None' = None, marker: 'MarkerType | None' = None, cmap: 'str | Colormap | None' = None, norm: 'str | Normalize | None' = None, vmin: 'float | None' = None, vmax: 'float | None' = None, alpha: 'float | None' = None, linewidths: 'float | Sequence[float] | None' = None, *, edgecolors: "Literal['face', 'none'] | ColorType | Sequence[ColorType] | None" = None, plotnonfinite: 'bool' = False, data=None, **kwargs) -> 'PathCollection'>
